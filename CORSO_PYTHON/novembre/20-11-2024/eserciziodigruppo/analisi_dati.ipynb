# %% [markdown]
# Analisi Dati di Gruppo

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

print("\nInformazioni Data Frame Car\n\n")

display(df.info())
# Out:
# Informazioni Data Frame Car
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188533 entries, 0 to 188532
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            188533 non-null  int64
#  1   brand         188533 non-null  object
#  2   model         188533 non-null  object
#  3   model_year    188533 non-null  int64
#  4   milage        188533 non-null  int64
#  5   fuel_type     183450 non-null  object
#  6   engine        188533 non-null  object
#  7   transmission  188533 non-null  object
#  8   ext_col       188533 non-null  object
#  9   int_col       188533 non-null  object
#  10  accident      186081 non-null  object
#  11  clean_title   167114 non-null  object
#  12  price         188533 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 18.7+ MB
# None

# %%
print("\nStampa elementi unici per colonna:\n\n")

print("Ci sono",len(set(df["brand"])),"brand diversi.")
print("Ci sono",len(set(df["model_year"])), "anni diversi.")
print("Ci sono",len(set(df["model"])),"modelli diversi.")
print("Ci sono",len(set(df["fuel_type"])), "fuel_type diversi.")
print("Ci sono",len(set(df["engine"])),"engine diversi.")
print("Ci sono",len(set(df["transmission"])), "trasmissioni diverse.")
print("Ci sono",len(set(df["ext_col"])),"ext_col diversi.")
print("Ci sono",len(set(df["int_col"])), "int_col diversi.")
print("Ci sono",len(set(df["accident"])), "accident diversi.")
print("Ci sono",len(set(df["clean_title"])),"clean_title diversi.")
print("Ci sono",len(set(df["price"])), "price diversi.")
# Out:
# Stampa elementi unici per colonna:
#
#
# Ci sono 57 brand diversi.
# Ci sono 34 anni diversi.
# Ci sono 1897 modelli diversi.
# Ci sono 8 fuel_type diversi.
# Ci sono 1117 engine diversi.
# Ci sono 52 trasmissioni diverse.
# Ci sono 319 ext_col diversi.
# Ci sono 156 int_col diversi.
# Ci sono 3 accident diversi.
# Ci sono 2 clean_title diversi.
# Ci sono 1569 price diversi.

# %%
#Rendiamo numerica la colonna Accident
df['accident'] = df['accident'].fillna(-1)
df["accident"].replace("None reported", 0, inplace = True)
df["accident"].replace("At least 1 accident or damage reported", 1, inplace = True)


#Rendiamo numerica la colonna clean_title

df['clean_title'] = df['clean_title'].fillna(0)
df["clean_title"].replace("Yes", 1, inplace = True)

#Pulizia colonna fuel_type

df['fuel_type'] = df['fuel_type'].fillna(-1)
# Out:
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\585391148.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["accident"].replace("None reported", 0, inplace = True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\585391148.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["accident"].replace("At least 1 accident or damage reported", 1, inplace = True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\585391148.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["accident"].replace("At least 1 accident or damage reported", 1, inplace = True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\585391148.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["clean_title"].replace("Yes", 1, inplace = True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\585391148.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["clean_title"].replace("Yes", 1, inplace = True)

# %%
model_price_mean = df.groupby('model_year')['price'].mean()
print("Media del prezzo per anno modello:\n", model_price_mean)
# Out:
# Media del prezzo per anno modello:
#  model_year
# 1974    74124.083333
# 1992    26957.000000
# 1993    38091.871429
# 1994    50181.760870
# 1995    38205.872549
# 1996    17370.894180
# 1997    14586.419872
# 1998    13442.169096
# 1999    10702.705776
# 2000    13796.912186
# 2001    19227.459583
# 2002    21286.650546
# 2003    17021.920252
# 2004    19401.310506
# 2005    26376.852029
# 2006    18351.585288
# 2007    19449.327112
# 2008    20384.406711
# 2009    21522.417894
# 2010    19964.660449
# 2011    18084.812450
# 2012    19806.953897
# 2013    23437.342702
# 2014    24758.274866
# 2015    30974.878567
# 2016    33531.819655
# 2017    37943.234329
# 2018    47707.568722
# 2019    49375.295606
# 2020    61556.784074
# 2021    65893.857951
# 2022    72732.327005
# 2023    95707.912305
# 2024    78006.067901
# Name: price, dtype: float64

# %%
df[df["price"]> 1000000]["price"].unique()
# Out:
# array([2954083, 1950995, 1599000])

# %%
def custom_range(start, stop):
    current = start
    while current < stop:
        if 2000 <= current < 10000:
            step = 2000
        elif 10000 <= current < 1000000:
            step = 20000
        elif 1000000 <= current <= 2954083:
            step = 1000000
        else:
            break  # Se fuori dai range specificati
        yield current
        current += step

df['PriceGroup'] = pd.cut(df['price'], bins= custom_range(2000,2954083), right= False)

price_group =  df.groupby('PriceGroup').agg(
    media_anno=('model_year', 'mean'),
    count_anni = ('model_year', 'count'),
    count_id =  ('id', 'count')
)

display(price_group)
# Out:
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\1537887921.py:17: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   price_group =  df.groupby('PriceGroup').agg(
#                      media_anno  count_anni  count_id
# PriceGroup
# [2000, 4000)        2006.582960        1561      1561
# [4000, 6000)        2006.799640        4447      4447
# [6000, 8000)        2007.664756        6804      6804
# [8000, 10000)       2008.260092        7382      7382
# [10000, 30000)      2013.760477       71922     71922
# [30000, 50000)      2018.550494       50471     50471
# [50000, 70000)      2019.438768       22080     22080
# [70000, 90000)      2020.062512       10046     10046
# [90000, 110000)     2020.270908        4747      4747
# [110000, 130000)    2019.866792        2132      2132
# [130000, 150000)    2019.876478        1692      1692
# [150000, 170000)    2019.609475         781       781
# [170000, 190000)    2019.862262         893       893
# [190000, 210000)    2019.114094         596       596
# [210000, 230000)    2017.950820         549       549
# [230000, 250000)    2020.292683         369       369
# [250000, 270000)    2019.869427         314       314
# [270000, 290000)    2020.769981         513       513
# [290000, 310000)    2018.045455          44        44
# [310000, 330000)    2018.987097         155       155
# [330000, 350000)    2019.060000          50        50
# [350000, 370000)    2021.658537          41        41
# [370000, 390000)            NaN           0         0
# [390000, 410000)    2018.028302         106       106
# [410000, 430000)    2018.539062         128       128
# [430000, 450000)    2020.513889          72        72
# [450000, 470000)    2020.701754          57        57
# [470000, 490000)    2018.883598         189       189
# [490000, 510000)    2019.875000          40        40
# [510000, 530000)            NaN           0         0
# [530000, 550000)            NaN           0         0
# [550000, 570000)            NaN           0         0
# [570000, 590000)            NaN           0         0
# [590000, 610000)    2019.246753          77        77
# [610000, 630000)            NaN           0         0
# [630000, 650000)    2020.000000          34        34
# [650000, 670000)            NaN           0         0
# [670000, 690000)            NaN           0         0
# [690000, 710000)    2019.933333          45        45
# [710000, 730000)            NaN           0         0
# [730000, 750000)    2020.458333          48        48
# [750000, 770000)            NaN           0         0
# [770000, 790000)            NaN           0         0
# [790000, 810000)            NaN           0         0
# [810000, 830000)            NaN           0         0
# [830000, 850000)            NaN           0         0
# [850000, 870000)            NaN           0         0
# [870000, 890000)            NaN           0         0
# [890000, 910000)            NaN           0         0
# [910000, 930000)            NaN           0         0
# [930000, 950000)            NaN           0         0
# [950000, 970000)            NaN           0         0
# [970000, 990000)            NaN           0         0
# [990000, 1010000)           NaN           0         0
# [1010000, 2010000)  2016.459184          98        98

# %%
df = df.drop(['model','fuel_type','engine', 'transmission', 'ext_col', 'int_col', 'id',"PriceGroup"], axis=1)

brands= df['brand'].unique()

df_brand_list= []
filtered_corr= []

for brand in brands:
    
    df_brand_list.append(df[df['brand'] == brand])

for df_brand in df_brand_list:
    brand_nome = df_brand['brand'].iloc[0]
    df_brand.drop('brand', axis=1, inplace=True)
    
    corr_matrix = df_brand.corr()  
    filtered = corr_matrix.where(((corr_matrix > 0.3) | (corr_matrix < -0.3))& (corr_matrix != 1)).stack()
    filtered_corr.append((f'Brand name: {brand_nome}\n',filtered))
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
    plt.title(f'Heatmap for Brand: {brand_nome}')
    
    #esportarle in png 

    plt.savefig(f'./image/{brand_nome}_heatmap.png',  bbox_inches='tight')
    
display(filtered_corr)
# Out:
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:20: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(10, 8))
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# C:\Users\ROBERTA\AppData\Local\Temp\ipykernel_10924\3905736440.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brand.drop('brand', axis=1, inplace=True)
# [('Brand name: MINI\n',
#   model_year  milage       -0.458579
#               price         0.534950
#   milage      model_year   -0.458579
#               price        -0.521113
#   price       model_year    0.534950
#               milage       -0.521113
#   dtype: float64),
#  ('Brand name: Lincoln\n',
#   model_year  milage       -0.698952
#               price         0.429888
#   milage      model_year   -0.698952
#               price        -0.460630
#   price       model_year    0.429888
#               milage       -0.460630
#   dtype: float64),
#  ('Brand name: Chevrolet\n',
#   model_year  milage       -0.630045
#   milage      model_year   -0.630045
#               accident      0.326432
#   accident    milage        0.326432
#   dtype: float64),
#  ('Brand name: Genesis\n',
#   model_year  milage       -0.675972
#   milage      model_year   -0.675972
#   dtype: float64),
#  ('Brand name: Mercedes-Benz\n',
#   model_year   milage        -0.655536
#                clean_title   -0.308800
#   milage       model_year    -0.655536
#   clean_title  model_year    -0.308800
#   dtype: float64),
#  ('Brand name: Audi\n',
#   model_year   milage        -0.703966
#                clean_title   -0.403918
#   milage       model_year    -0.703966
#                clean_title    0.364385
#                price         -0.339701
#   clean_title  model_year    -0.403918
#                milage         0.364385
#   price        milage        -0.339701
#   dtype: float64),
#  ('Brand name: Ford\n',
#   model_year  milage       -0.669967
#   milage      model_year   -0.669967
#   dtype: float64),
#  ('Brand name: BMW\n',
#   model_year  milage       -0.674320
#               price         0.341063
#   milage      model_year   -0.674320
#               price        -0.386157
#   price       model_year    0.341063
#               milage       -0.386157
#   dtype: float64),
#  ('Brand name: Tesla\n',
#   model_year  milage       -0.619798
#   milage      model_year   -0.619798
#   dtype: float64),
#  ('Brand name: Cadillac\n',
#   model_year  milage       -0.650689
#   milage      model_year   -0.650689
#   dtype: float64),
#  ('Brand name: Land\n',
#   model_year  milage       -0.767152
#   milage      model_year   -0.767152
#               accident      0.303053
#   accident    milage        0.303053
#   dtype: float64),
#  ('Brand name: GMC\n',
#   model_year  milage       -0.690151
#   milage      model_year   -0.690151
#   dtype: float64),
#  ('Brand name: Toyota\n',
#   model_year   milage        -0.697926
#                clean_title   -0.320321
#   milage       model_year    -0.697926
#   clean_title  model_year    -0.320321
#   dtype: float64),
#  ('Brand name: Hyundai\n',
#   model_year   milage        -0.677759
#                clean_title   -0.421746
#   milage       model_year    -0.677759
#                clean_title    0.357665
#   clean_title  model_year    -0.421746
#                milage         0.357665
#   dtype: float64),
#  ('Brand name: Volvo\n',
#   model_year  milage       -0.600466
#               price         0.406699
#   milage      model_year   -0.600466
#               price        -0.438068
#   price       model_year    0.406699
#               milage       -0.438068
#   dtype: float64),
#  ('Brand name: Volkswagen\n',
#   model_year  milage       -0.579730
#               price         0.374359
#   milage      model_year   -0.579730
#               price        -0.434360
#   price       model_year    0.374359
#               milage       -0.434360
#   dtype: float64),
#  ('Brand name: Buick\n',
#   model_year   milage        -0.636786
#                clean_title   -0.329273
#                price          0.381457
#   milage       model_year    -0.636786
#                clean_title    0.337726
#                price         -0.350097
#   clean_title  model_year    -0.329273
#                milage         0.337726
#   price        model_year     0.381457
#                milage        -0.350097
#   dtype: float64),
#  ('Brand name: Rivian\n',
#   model_year   milage        -0.468303
#   milage       model_year    -0.468303
#   accident     clean_title    0.474255
#   clean_title  accident       0.474255
#   dtype: float64),
#  ('Brand name: RAM\n',
#   model_year  milage       -0.681949
#   milage      model_year   -0.681949
#   dtype: float64),
#  ('Brand name: Hummer\n',
#   model_year  price         0.321702
#   milage      price        -0.310059
#   price       model_year    0.321702
#               milage       -0.310059
#   dtype: float64),
#  ('Brand name: Alfa\n',
#   model_year  milage       -0.678682
#               price         0.356567
#   milage      model_year   -0.678682
#               price        -0.318510
#   price       model_year    0.356567
#               milage       -0.318510
#   dtype: float64),
#  ('Brand name: INFINITI\n',
#   model_year  milage       -0.631706
#   milage      model_year   -0.631706
#   dtype: float64),
#  ('Brand name: Jeep\n',
#   model_year   milage        -0.779154
#                accident      -0.333123
#                clean_title   -0.334494
#                price          0.453267
#   milage       model_year    -0.779154
#                accident       0.389004
#                clean_title    0.310250
#                price         -0.468507
#   accident     model_year    -0.333123
#                milage         0.389004
#   clean_title  model_year    -0.334494
#                milage         0.310250
#   price        model_year     0.453267
#                milage        -0.468507
#   dtype: float64),
#  ('Brand name: Porsche\n',
#   model_year  milage       -0.552357
#   milage      model_year   -0.552357
#   dtype: float64),
#  ('Brand name: McLaren\n', Series([], dtype: float64)),
#  ('Brand name: Honda\n',
#   model_year   milage        -0.591168
#                clean_title   -0.398457
#   milage       model_year    -0.591168
#                clean_title    0.356960
#   clean_title  model_year    -0.398457
#                milage         0.356960
#   dtype: float64),
#  ('Brand name: Lexus\n',
#   model_year   milage        -0.727936
#                accident      -0.319644
#                clean_title   -0.341249
#   milage       model_year    -0.727936
#                accident       0.350940
#                clean_title    0.324147
#   accident     model_year    -0.319644
#                milage         0.350940
#   clean_title  model_year    -0.341249
#                milage         0.324147
#   dtype: float64),
#  ('Brand name: Dodge\n',
#   model_year  milage       -0.694481
#               accident     -0.326286
#   milage      model_year   -0.694481
#               accident      0.383372
#               price        -0.324846
#   accident    model_year   -0.326286
#               milage        0.383372
#   price       milage       -0.324846
#   dtype: float64),
#  ('Brand name: Nissan\n',
#   model_year   milage        -0.582365
#                clean_title   -0.321707
#                price          0.342261
#   milage       model_year    -0.582365
#                price         -0.397418
#   clean_title  model_year    -0.321707
#   price        model_year     0.342261
#                milage        -0.397418
#   dtype: float64),
#  ('Brand name: Jaguar\n',
#   model_year  milage       -0.476197
#   milage      model_year   -0.476197
#   dtype: float64),
#  ('Brand name: Acura\n',
#   model_year   milage        -0.706921
#                clean_title   -0.476400
#                price          0.468285
#   milage       model_year    -0.706921
#                accident       0.362991
#                clean_title    0.414091
#                price         -0.476469
#   accident     milage         0.362991
#   clean_title  model_year    -0.476400
#                milage         0.414091
#   price        model_year     0.468285
#                milage        -0.476469
#   dtype: float64),
#  ('Brand name: Kia\n',
#   model_year   milage        -0.760700
#                accident      -0.307384
#                clean_title   -0.350654
#                price          0.382272
#   milage       model_year    -0.760700
#                accident       0.332134
#                clean_title    0.311900
#                price         -0.382357
#   accident     model_year    -0.307384
#                milage         0.332134
#   clean_title  model_year    -0.350654
#                milage         0.311900
#   price        model_year     0.382272
#                milage        -0.382357
#   dtype: float64),
#  ('Brand name: Mitsubishi\n',
#   model_year  milage       -0.306686
#   milage      model_year   -0.306686
#   dtype: float64),
#  ('Brand name: Rolls-Royce\n',
#   model_year  milage       -0.453088
#   milage      model_year   -0.453088
#   dtype: float64),
#  ('Brand name: Maserati\n',
#   model_year  milage       -0.605156
#               accident     -0.308531
#               price         0.324414
#   milage      model_year   -0.605156
#               price        -0.339195
#   accident    model_year   -0.308531
#   price       model_year    0.324414
#               milage       -0.339195
#   dtype: float64),
#  ('Brand name: Pontiac\n', Series([], dtype: float64)),
#  ('Brand name: Saturn\n',
#   model_year  milage       -0.406381
#               price         0.305041
#   milage      model_year   -0.406381
#               price        -0.513604
#   price       model_year    0.305041
#               milage       -0.513604
#   dtype: float64),
#  ('Brand name: Bentley\n',
#   model_year   milage        -0.583488
#   milage       model_year    -0.583488
#   accident     clean_title    0.310130
#   clean_title  accident       0.310130
#   dtype: float64),
#  ('Brand name: Mazda\n',
#   model_year  milage       -0.61121
#   milage      model_year   -0.61121
#   dtype: float64),
#  ('Brand name: Subaru\n',
#   model_year  milage       -0.553708
#               price         0.425806
#   milage      model_year   -0.553708
#               price        -0.486116
#   price       model_year    0.425806
#               milage       -0.486116
#   dtype: float64),
#  ('Brand name: Ferrari\n',
#   model_year  milage       -0.525155
#   milage      model_year   -0.525155
#   dtype: float64),
#  ('Brand name: Aston\n',
#   model_year  milage       -0.520985
#   milage      model_year   -0.520985
#   dtype: float64),
#  ('Brand name: Lamborghini\n',
#   model_year   milage        -0.415872
#                clean_title   -0.352557
#   milage       model_year    -0.415872
#   clean_title  model_year    -0.352557
#   dtype: float64),
#  ('Brand name: Chrysler\n',
#   model_year  milage       -0.593726
#   milage      model_year   -0.593726
#   dtype: float64),
#  ('Brand name: Lucid\n',
#   model_year   milage        -0.463354
#                price          0.363247
#   milage       model_year    -0.463354
#   accident     clean_title    0.408597
#   clean_title  accident       0.408597
#   price        model_year     0.363247
#   dtype: float64),
#  ('Brand name: Lotus\n',
#   model_year   milage        -0.456054
#                accident      -0.472856
#                price          0.652633
#   milage       model_year    -0.456054
#                accident       0.319871
#                price         -0.546601
#   accident     model_year    -0.472856
#                milage         0.319871
#                clean_title    0.306814
#   clean_title  accident       0.306814
#   price        model_year     0.652633
#                milage        -0.546601
#   dtype: float64),
#  ('Brand name: Scion\n',
#   model_year  milage       -0.310814
#               price         0.465434
#   milage      model_year   -0.310814
#               price        -0.478610
#   price       model_year    0.465434
#               milage       -0.478610
#   dtype: float64),
#  ('Brand name: smart\n',
#   model_year   milage        -0.746287
#                accident      -0.450910
#                clean_title   -0.998443
#                price          0.997741
#   milage       model_year    -0.746287
#                accident       0.930624
#                clean_title    0.782257
#                price         -0.789316
#   accident     model_year    -0.450910
#                milage         0.930624
#                clean_title    0.500000
#                price         -0.509851
#   clean_title  model_year    -0.998443
#                milage         0.782257
#                accident       0.500000
#                price         -0.999935
#   price        model_year     0.997741
#                milage        -0.789316
#                accident      -0.509851
#                clean_title   -0.999935
#   dtype: float64),
#  ('Brand name: Karma\n',
#   model_year   milage        -0.781564
#                accident      -0.594453
#                clean_title   -0.513144
#                price          0.539630
#   milage       model_year    -0.781564
#                accident       0.576803
#                clean_title    0.333918
#                price         -0.515631
#   accident     model_year    -0.594453
#                milage         0.576803
#                price         -0.367836
#   clean_title  model_year    -0.513144
#                milage         0.333918
#                price         -0.354023
#   price        model_year     0.539630
#                milage        -0.515631
#                accident      -0.367836
#                clean_title   -0.354023
#   dtype: float64),
#  ('Brand name: Plymouth\n',
#   milage    accident   -0.418250
#             price      -0.339761
#   accident  milage     -0.418250
#   price     milage     -0.339761
#   dtype: float64),
#  ('Brand name: Suzuki\n',
#   model_year   clean_title   -0.643569
#   milage       accident       0.331885
#   accident     milage         0.331885
#                clean_title    0.333333
#                price         -0.329135
#   clean_title  model_year    -0.643569
#                accident       0.333333
#                price         -0.659745
#   price        accident      -0.329135
#                clean_title   -0.659745
#   dtype: float64),
#  ('Brand name: FIAT\n',
#   model_year   milage        -0.592601
#                price          0.479372
#   milage       model_year    -0.592601
#                price         -0.369788
#   accident     clean_title    0.540128
#   clean_title  accident       0.540128
#   price        model_year     0.479372
#                milage        -0.369788
#   dtype: float64),
#  ('Brand name: Saab\n',
#   model_year  milage       -0.535001
#               price         0.583141
#   milage      model_year   -0.535001
#               price        -0.508817
#   accident    price        -0.377665
#   price       model_year    0.583141
#               milage       -0.508817
#               accident     -0.377665
#   dtype: float64),
#  ('Brand name: Bugatti\n',
#   model_year   clean_title   -0.708559
#                price         -0.386639
#   milage       clean_title    0.340505
#   clean_title  model_year    -0.708559
#                milage         0.340505
#   price        model_year    -0.386639
#   dtype: float64),
#  ('Brand name: Mercury\n',
#   accident     clean_title    0.468298
#   clean_title  accident       0.468298
#   dtype: float64),
#  ('Brand name: Polestar\n',
#   model_year   milage        -0.811010
#                clean_title   -0.608627
#                price          0.437134
#   milage       model_year    -0.811010
#                clean_title    0.527372
#                price         -0.502653
#   accident     clean_title    0.353553
#   clean_title  model_year    -0.608627
#                milage         0.527372
#                accident       0.353553
#                price         -0.390173
#   price        model_year     0.437134
#                milage        -0.502653
#                clean_title   -0.390173
#   dtype: float64),
#  ('Brand name: Maybach\n',
#   model_year  price        -0.492960
#   milage      accident      0.948776
#               price        -0.688157
#   accident    milage        0.948776
#               price        -0.882148
#   price       model_year   -0.492960
#               milage       -0.688157
#               accident     -0.882148
#   dtype: float64)]
